# %% [markdown]
# # Data and Data Loaders

# %% [markdown]
# ## Imports

# %%
from torch.utils.data import DataLoader

from modelling.data import FilmReviewSequences, get_data
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 3
#       1 from torch.utils.data import DataLoader
# ----> 3 from modelling.data import FilmReviewSequences, get_data
#
# ModuleNotFoundError: No module named 'modelling'

# %% [markdown]
# ## The Dataset

# %%
train_data, test_data = get_data()

train_data.head(5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 train_data, test_data = get_data()
#       3 train_data.head(5)
#
# NameError: name 'get_data' is not defined
